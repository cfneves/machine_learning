# %% [markdown]
# ---
# ## **Aula {NN}**: {Tema Completo}
# **Autor:** Cláudio Ferreira Neves · Especialista em Ciência de Dados e IA
#
# > Material didático autoral. Reprodução sem crédito ao autor é considerada plágio.
# ---

# %% [markdown]
# ## 📋 Objetivos desta aula
#
# Ao final desta aula você será capaz de:
#
# - ✅ {Objetivo 1 — verbo no infinitivo: "Entender...", "Aplicar...", "Comparar..."}
# - ✅ {Objetivo 2}
# - ✅ {Objetivo 3}
# - ✅ {Objetivo 4}
#
# **Pré-requisitos:** {O que o aluno precisa saber antes desta aula — ex: Python básico, NumPy, Pandas}
#
# **Duração estimada:** {N} horas

# %% [markdown]
# ## 🗺️ Roteiro da aula
#
# | # | Seção | Tempo estimado |
# |---|-------|----------------|
# | 1 | {Nome da Seção 1} | ~{N} min |
# | 2 | {Nome da Seção 2} | ~{N} min |
# | 3 | {Nome da Seção 3} | ~{N} min |
# | 4 | {Nome da Seção 4} | ~{N} min |

# %%
# ============================================================
# IMPORTAÇÕES — todas as bibliotecas usadas nesta aula
# ============================================================

import numpy as np                          # arrays e operações numéricas
import pandas as pd                         # tabelas de dados (DataFrames)
import matplotlib.pyplot as plt             # criação de gráficos
import seaborn as sns                       # gráficos estatísticos

# Adicione imports do scikit-learn conforme necessário:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import Pipeline

# Configurações visuais globais
plt.rcParams['figure.figsize'] = (8, 5)    # tamanho padrão dos gráficos
plt.rcParams['axes.grid'] = True           # grade habilitada por padrão

print('✅ Bibliotecas importadas com sucesso!')

# %% [markdown]
# ---
# ## ➡️ Seção 1 — {Nome da Seção}
#
# {Explicação do conceito em linguagem simples — 3 a 5 linhas.}
#
# **Analogia:** {Analogia do cotidiano para tornar o conceito concreto — ex: "É como tentar achar a melhor reta num papel quadriculado..."}
#
# **Onde é usado:** {Exemplo prático real de onde esse conceito aparece no mercado}
#
# > **Fórmula:**
# > $${formula LaTeX}$$
# > Onde:
# > - **{símbolo}** = {o que representa}
# > - **{símbolo}** = {o que representa}

# %% [markdown]
# ### 1.1 {Sub-passo da seção}
#
# {Explicação específica do que o código abaixo faz, antes de mostrar o código.}

# %%
# ------------------------------------------------
# {Título descritivo do bloco de código}
# ------------------------------------------------

np.random.seed(42)  # garante que os resultados sejam sempre iguais ao repetir

# {Código comentado linha a linha}
# Cada linha não óbvia deve ter um comentário explicando o que faz e por quê
X = np.array([])    # {o que X representa neste contexto}
y = np.array([])    # {o que y representa neste contexto}

print(f'Shape de X: {X.shape}')  # shape = dimensões do array (linhas, colunas)
print(f'Shape de y: {y.shape}')

# %% [markdown]
# ### 1.2 {Sub-passo da seção}
#
# {Explicação do que acontece a seguir.}

# %%
# {Código da sub-etapa 1.2}
pass

# %% [markdown]
# > ### 🎯 Momento de Praticar
# >
# > **Exercício {N}:** {Enunciado claro do exercício — o que o aluno deve fazer}
# >
# > **Dica:** {Pista que ajuda sem entregar a resposta completa}
# >
# > **Esperado:** {Como o aluno sabe que acertou — ex: "O gráfico deve mostrar uma reta ascendente"}

# %%
# ✏️ Escreva sua solução aqui

# %% [markdown]
# ---
# ## ➡️ Seção 2 — {Nome da Seção}
#
# {Explicação do conceito em linguagem simples.}
#
# **Analogia:** {Analogia}
#
# > **Fórmula:**
# > $${formula LaTeX}$$

# %% [markdown]
# ### 2.1 {Sub-passo}

# %%
# {Código da seção 2}
pass

# %% [markdown]
# > ### 🎯 Momento de Praticar
# >
# > **Exercício {N}:** {Enunciado}
# >
# > **Dica:** {Pista}

# %%
# ✏️ Escreva sua solução aqui

# %% [markdown]
# ---
# ## ➡️ Seção {N} — {Nome da Seção}
#
# <!--
#   Repita o bloco acima (## ➡️ Seção ... + sub-etapas + 🎯 Praticar)
#   para cada seção adicional da aula.
# -->

# %% [markdown]
# ---
# ## 📌 Resumo da Aula
#
# ### O que aprendemos hoje
#
# | Conceito | O que é | Quando usar |
# |----------|---------|-------------|
# | {Conceito 1} | {Definição em uma linha} | {Situação de uso} |
# | {Conceito 2} | {Definição em uma linha} | {Situação de uso} |
# | {Conceito 3} | {Definição em uma linha} | {Situação de uso} |
# | {Conceito 4} | {Definição em uma linha} | {Situação de uso} |
#
# ### ✅ Checklist de aprendizado
#
# Antes de avançar, confirme que você consegue:
#
# - [ ] {Competência 1 — ex: "Explicar a diferença entre X e Y sem consultar o material"}
# - [ ] {Competência 2 — ex: "Implementar X usando sklearn com 5 linhas de código"}
# - [ ] {Competência 3}
# - [ ] {Competência 4}
#
# ### 🚀 Próximos passos
#
# Na **Aula {NN+1}** vamos aprender {tema da próxima aula}, que é necessário porque {motivo de continuidade}.
#
# ---
# *Material autoral — Cláudio Ferreira Neves · SENAI/SC*
