# %% [markdown]
# ---
# ## **Curso**: Pós-graduação em Ciência de Dados e Inteligência Artificial
# ## **Unidade Curricular**: Machine Learning
# ## **Professor**: Matheus Vanzan
# ## **Data**: 11/09/2025 (Aula Síncrona 2)
# ---

# %% [markdown]
# # **📌 CRISP-DM - Cross Industry Standard Process for Data Mining**

# %% [markdown]
# O **CRISP-DM (Cross Industry Standard Process for Data Mining)** é a metodologia mais utilizada para guiar projetos de ciência de dados e mineração de dados.
# Ela organiza o processo em **seis etapas principais**, que formam um ciclo iterativo:
#
# 1. **Entendimento do Negócio:** definir claramente o problema a ser resolvido, os objetivos do projeto e os critérios de sucesso.
# 2. **Entendimento dos Dados:** coletar os dados disponíveis, avaliar sua qualidade e compreender suas características. Muitas vezes essa etapa é revisitada em conjunto com o entendimento do negócio.
# 3. **Preparação dos Dados:** limpar, transformar e organizar os dados para que estejam prontos para a modelagem. Inclui tratamento de valores ausentes, remoção de outliers, criação de variáveis (*feature engineering*) e normalização.
# 4. **Modelagem:** selecionar os algoritmos de Machine Learning mais adequados, ajustar hiperparâmetros e treinar os modelos utilizando os dados preparados.
# 5. **Avaliação:** verificar se os modelos atingem os objetivos definidos no início. Além das métricas técnicas, deve-se avaliar se as soluções fazem sentido para o contexto do negócio.
# 6. **Implantação:** disponibilizar o modelo para uso real, seja em forma de relatórios, dashboards ou integração com sistemas. Essa etapa garante que o trabalho gere valor prático.
#
# > Importante: O CRISP-DM **não é linear**: ele é cíclico e flexível. Em qualquer etapa pode ser necessário retornar às anteriores, seja para refinar os dados, ajustar os modelos ou até redefinir objetivos de negócio.

# %% [markdown]
# # **📌 Análise Exploratória de Dados**

# %% [markdown]
# ## **📊 Palmer Penguins Dataset**
# Fonte: https://allisonhorst.github.io/palmerpenguins/index.html

# %% [markdown]
# O *Palmer Penguins dataset* contém informações sobre três espécies de pinguins (Adélie, Gentoo e Chinstrap) coletadas no arquipélago Palmer, na Antártida.
#
# <br>**Conheça os pinguins do Arquipélago Palmer:**
#
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/lter_penguins.png" width="500">
#
# **A base inclui dados sobre**:
#
# - **Espécie (`species`)**: Nome científico (Adélie, Gentoo ou Chinstrap).
# - **Ilha (`island`)**: Em qual das três ilhas (Biscoe, Dream, Torgersen) o pinguim foi observado.
# - **Comprimento do bico (`bill_length_mm`)**: Em milímetros.
# - **Profundidade do bico (`bill_depth_mm`)**: Em milímetros.
# - **Comprimento da nadadeira (`flipper_length_mm`)**: Em milímetros.
# - **Massa corporal (`body_mass_g`)**: Em gramas.
# - **Sexo (`sex`)**: Masculino ou feminino (quando identificado).
# - **Ano (`year`)**: Ano de coleta dos dados.
#
#
#
# <br>**Dimensões do Bico:**
#
# O culmen é a crista superior do bico de uma ave. No conjunto de dados, o comprimento e a profundidade do culmen foram atualizados para as variáveis nomeadas `bill_length_mm` e `bill_depth_mm`.
#
# O comprimento e a profundidade do bico/culmen são medidos conforme mostrado abaixo:
#
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/culmen_depth.png" width="500">

# %% [markdown]
# ### **1. Obtenção dos Dados**

# %%
# !pip install palmerpenguins --quiet

# %%
# !ls
# Out:
# sample_data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from palmerpenguins import load_penguins

# %%
df = load_penguins()

# %% [markdown]
# ### **2. Entendeminto da Estrutura do Dataset**

# %% [markdown]
# Nesta etapa, o objetivo é conhecer a composição do conjunto de dados. Isso inclui identificar quais são as variáveis disponíveis, seus tipos (numéricos, categóricos, etc.), a quantidade de entradas (linhas), identificar se há dados faltantes ou duplicados e compreender o contexto representado por cada coluna. Esse entendimento inicial é essencial para orientar as próximas fases da análise.

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# ...

# %%
df.tail()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009

# %%
df.shape
# Out:
# (344, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
df.nunique()
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# year                   3
# dtype: int64

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
for column in df.columns:
    print(f"{column}: {df[column].unique()}")
# Out:
# species: ['Adelie' 'Gentoo' 'Chinstrap']
# island: ['Torgersen' 'Biscoe' 'Dream']
# bill_length_mm: [39.1 39.5 40.3  nan 36.7 39.3 38.9 39.2 34.1 42.  37.8 41.1 38.6 34.6
#  36.6 38.7 42.5 34.4 46.  37.7 35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2
#  40.9 36.4 42.2 37.6 39.8 36.5 40.8 36.  44.1 37.  39.6 37.5 42.3 40.1
#  35.  34.5 41.4 39.  35.7 41.3 41.6 35.5 41.8 33.5 39.7 45.8 42.8 36.2
#  42.1 42.9 35.1 37.3 36.3 36.9 38.3 34.  38.1 33.1 43.2 41.  45.6 42.7
#  40.2 35.2 41.5 38.5 43.1 36.8 35.6 32.1 40.7 46.1 50.  48.7 47.6 46.5
#  45.4 46.7 43.3 46.8 49.  45.5 48.4 49.3 49.2 46.2 50.2 45.1 46.3 44.5
#  47.8 48.2 47.3 59.6 49.1 42.6 44.4 44.  49.6 45.3 50.5 43.6 44.9 45.2
#  46.6 48.5 50.1 45.  43.8 50.4 45.7 54.3 49.8 49.5 43.5 50.7 47.7 46.4
#  48.6 47.5 51.1 52.5 47.4 50.8 43.4 51.3 52.1 52.2 49.4 46.9 55.9 47.2
#  41.7 53.4 48.1 51.5 55.1 48.8 49.9 52.7 51.7 47.  52.  45.9 50.3 58.
#  42.4 50.6 52.8 54.2 51.  49.7 53.5 50.9 51.4 51.9 55.8]
# ...

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
# Verifica linhas duplicadas
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
# Verifica linhas duplicadas com base em colunas específicas
df[df.duplicated(subset=['species', 'island', 'bill_length_mm', 'bill_depth_mm'], keep=False)]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 28   Adelie  Biscoe            37.9           18.6              172.0
# 52   Adelie  Biscoe            35.0           17.9              190.0
# 100  Adelie  Biscoe            35.0           17.9              192.0
# 104  Adelie  Biscoe            37.9           18.6              193.0
# 173  Gentoo  Biscoe            45.1           14.5              215.0
# 184  Gentoo  Biscoe            45.1           14.5              207.0
# 196  Gentoo  Biscoe            50.5           15.9              222.0
# 199  Gentoo  Biscoe            50.5           15.9              225.0
#
#      body_mass_g     sex  year
# 28        3150.0  female  2007
# 52        3450.0  female  2008
# 100       3725.0  female  2009
# 104       2925.0  female  2009
# 173       5000.0  female  2007
# 184       5050.0  female  2007
# 196       5550.0    male  2008
# 199       5400.0    male  2008

# %% [markdown]
# **ANOTAÇÕES:**
#
# > Existem valores nulos nas colunas: 'bill_length_mm', 'bill_depth_mm' 'flipper_length_mm', 'body_mass_g' e 'sex'
#
#
# > Tipos de variáveis:
# 1. Variáveis categóricas: 'species', 'island', 'sex'
# 2. Variáveis numéricas continuas: 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm, 'body_mass_g
# 3. Variáveis numéricas discretas: 'year'

# %% [markdown]
# ### **3. Tratamento de Valores Ausentes**

# %% [markdown]
# Aqui, buscamos tratar os dados faltantes. A forma como lidamos com valores ausentes pode influenciar diretamente a qualidade das análises, portanto, essa etapa envolve decisões importantes, como remoção, imputação ou até mesmo manutenção controlada desses valores.

# %% [markdown]
# > *Remover linhas com valores ausentes:*
# * `df.dropna()`  # Remove linhas que possuem qualquer valor ausente
# * `df.dropna(how='all')`  # Remove apenas linhas onde todas as colunas são NaN
#
# > *Remover colunas com valores ausentes:*
# * `df.dropna(axis=1)`  # Remove colunas com qualquer valor ausente
# * `df.dropna(axis=1, thresh=2)`  # Mantém colunas com pelo menos 2 valores não nulos
#
# > *Preenchimento com um valor fixo:*
# * `df.fillna(0)`  # Substitui todos os valores NaN por 0
# * `df['col1'].fillna('desconhecido', inplace=True)`  # Para colunas categóricas
#
# > *Preenchimento com a média, mediana ou moda:*
# * `df['col3'].fillna(df['col3'].mean(), inplace=True)`  # Média
# * `df['col3'].fillna(df['col3'].median(), inplace=True)`  # Mediana
# * `df['col3'].fillna(df['col3'].mode()[0], inplace=True)`  # Moda

# %%
df.dropna(inplace=True) # Remover todas as linhas com valores ausentes

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
df.shape
# Out:
# (333, 8)

# %% [markdown]
# **ANOTAÇÕES:**

# %% [markdown]
# ### **4. Tratamento de Linhas Duplicadas**

# %% [markdown]
# Nesta fase, o foco é tratar possíveis duplicatas no conjunto de dados. Linhas repetidas podem enviesar estatísticas e gerar interpretações incorretas. O tratamento adequado garante que a análise represente com fidelidade as observações reais do fenômeno estudado.

# %% [markdown]
# > *Remover linhas duplicadas:*
# * `df.drop_duplicates(keep='first', inplace='True')`
#
# > *Remover linhas duplicadas considerando colunas específicas:*
# * `df.drop_duplicates(subset=['species', 'island', 'bill_length_mm', 'bill_depth_mm'], keep='first', inplace='True')`

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# **ANOTAÇÕES:**

# %% [markdown]
# ### **5. Análise Univariada**

# %% [markdown]
# A análise univariada é dedicada a examinar cada variável individualmente. O objetivo é entender a distribuição dos dados, identificar padrões, assimetrias, e possíveis anomalias. Essa compreensão é fundamental para avaliar a qualidade e a variabilidade de cada atributo do conjunto de dados.
#
# > ***Gráficos comumente utilizados:***
# - **Histogramas**: para visualizar a distribuição de variáveis numéricas.
# - **Boxplots**: para identificar a dispersão e possíveis outliers.
# - **Gráficos de barras (bar plots)**: para variáveis categóricas, permitindo observar a frequência de cada categoria.
# - **Gráficos de densidade (KDE plots)**: para uma visualização mais suave da distribuição de variáveis contínuas.

# %% [markdown]
# > ***O que é um resumo estatístico descritivo e como interpretá-lo?***
#
# Um **resumo estatístico descritivo** fornece **informações essenciais** sobre a **distribuição, dispersão e tendência central** dos dados, auxiliando na compreensão inicial do conjunto analisado.
#
# Principais indicadores:
#
# - **count**: Número de valores **não nulos** em cada coluna — útil para detectar **ausência de dados**.
# - **mean**: A **média aritmética** dos valores — representa a **tendência central** dos dados, ou seja, o valor médio da variável..
# - **std**: O **desvio padrão** — indica o **grau de dispersão** dos dados em relação à média. Quanto maior, mais espalhados estão os dados.
# - **min**: O **menor valor** observado — útil para identificar **limites inferiores** e possíveis **outliers**.
# - **quartis**:
#   - **25% (1º quartil)**: Indica que **25% dos dados** são menores ou iguais a esse valor.
#   - **50% (2º quartil ou mediana)**: Valor que separa a metade inferior e superior dos dados — uma medida robusta da centralidade.
#   - **75% (3º quartil)**: Indica que **75% dos dados** são menores ou iguais a esse valor.
# - **max**: O **maior valor** observado — revela **limites superiores** e possíveis **outliers**.
#
# > ***Como interpretar um resumo estatístico:***
# 1. **Média próxima da mediana** → Sugere uma **distribuição simétrica**.
# 2. **Média distante da mediana** → Pode indicar **assimetria** (distribuição enviesada).
# 3. **Desvio padrão alto** → Os dados estão **muito dispersos** ao redor da média.
# 4. **Intervalo interquartílico (IQR = Q3 - Q1)** → Mede a **dispersão central** e ajuda a identificar **valores atípicos**.
# 5. **Mínimo ou máximo muito distantes dos quartis** → Indício de **outliers** ou dados extremos.
# 6. **Contagem baixa** → Pode sugerir **ausência ou falhas de preenchimento** em parte dos dados.

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
# Mostra apenas as colunas numéricas
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# #### **➡️ Quantidades**

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
df['species'].value_counts(normalize=True) * 100
# Out:
# species
# Adelie       43.843844
# Gentoo       35.735736
# Chinstrap    20.420420
# Name: proportion, dtype: float64

# %%
df['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
df['island'].value_counts(normalize=True) * 100
# Out:
# island
# Biscoe       48.948949
# Dream        36.936937
# Torgersen    14.114114
# Name: proportion, dtype: float64

# %%
df['island'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %%
df['sex'].value_counts(normalize=True) * 100
# Out:
# sex
# male      50.45045
# female    49.54955
# Name: proportion, dtype: float64

# %%
df['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df['year'].value_counts(normalize=True) * 100
# Out:
# year
# 2009    35.135135
# 2008    33.933934
# 2007    30.930931
# Name: proportion, dtype: float64

# %%
df['year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df[df['island'] == 'Biscoe']
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 270  Gentoo  Biscoe            47.2           13.7              214.0
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 20        3400.0  female  2007
# 21        3600.0    male  2007
# ...

# %%
df[df['island'] == 'Biscoe']['species'].value_counts().plot(kind='bar', title='Biscoe')
# Out:
# <Axes: title={'center': 'Biscoe'}, xlabel='species'>

# %%
df[df['island'] == 'Dream']['species'].value_counts().plot(kind='bar', title='Dream')
# Out:
# <Axes: title={'center': 'Dream'}, xlabel='species'>

# %%
df[df['island'] == 'Torgersen']['species'].value_counts().plot(kind='bar', title='Torgersen')
# Out:
# <Axes: title={'center': 'Torgersen'}, xlabel='species'>

# %% [markdown]
# #### **➡️  Histrogramas**
#
# > ***O que é um histograma e como interpretá-lo?***
#
# O **histograma** é uma representação gráfica que mostra a **distribuição de frequências** de um conjunto de dados numéricos. Ele permite visualizar como os valores de uma variável estão distribuídos ao longo de intervalos (ou **bins**), facilitando a identificação de **padrões, simetrias, assimetrias e dispersão**.
#
# Um histograma é composto por:
# - **Barras verticais**: Cada barra representa um intervalo de valores (bin) e sua altura indica a **frequência absoluta** (ou relativa) de dados naquele intervalo.
# - **Eixo horizontal (x)**: Mostra os intervalos dos valores da variável.
# - **Eixo vertical (y)**: Indica o número de ocorrências (frequência) em cada intervalo.
#
# > ***Como interpretar um histograma:***
# 1. **Distribuição simétrica (ex: forma de sino)** → Sugere que os dados seguem uma distribuição normal.
# 2. **Distribuição assimétrica à direita (cauda longa à direita)** → Indica que há valores mais extremos acima da média.
# 3. **Distribuição assimétrica à esquerda (cauda longa à esquerda)** → Indica que há valores mais extremos abaixo da média.
# 4. **Picos ou múltiplos modos** → Podem indicar a presença de **grupos distintos** ou **multimodalidade**.
# 5. **Largura dos bins**: Pode influenciar a leitura — bins muito largos podem esconder padrões, e bins muito estreitos podem gerar “ruído visual”.
#
# > Um **histograma unimodal ou simétrico** centraliza os dados na média (medida central) e possui características por meio da distribuição da média e do desvio padrão. Uma característica do histograma unimodal ou simétrico é conter a partir do centro do gráfico o maior número de dados.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/1/15/Symmetric-histogram.png" width="500">
#
# > Um histograma é **distorcido à direita** quando a distribuição de dados indica a ocorrência de altos valores com baixa frequência.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/1/12/Skewed-right.png" width="500">
#
# > Um histograma é **distorcido à esquerda** quando a frequência dos dados está concentrada nos altos valores e sendo chamada de distorcida à esquerda. Observa–se que há mais informações acima da média devido a falta de simetria.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7b/Skewed-left.png" width="500">
#
# > Um **histograma é bimodal** quando há o aparecimento de dois picos.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bimodal-histogram.png" width="500">
#
# > Um **histograma é multimodal** quando há o aparecimento de vários picos.
#
# <img src="http://upload.wikimedia.org/wikipedia/commons/3/39/Multimodal.png" width="500">
#
# Um histograma tem o **formato Platô** quando suas barras tem praticamente os mesmo tamanhos de altura. Isto ocorre quando existem várias distribuições juntas com médias diferentes.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7b/Symmetric2.png" width="500">

# %%
bins = int(np.sqrt(len(df)))

# %%
df['bill_length_mm'].plot(kind='hist', bins=bins, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bill_depth_mm'].plot(kind='hist', bins=bins, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['flipper_length_mm'].plot(kind='hist', bins=bins, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['body_mass_g'].plot(kind='hist', bins=bins, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### **➡️ Boxplots**
#
# > ***O que é um Boxplot e como interpretá-lo?***
#
# O **boxplot**, ou **diagrama de caixa**, é uma representação gráfica que resume a distribuição de um conjunto de dados numéricos. Ele fornece informações sobre a **dispersão, tendência central e presença de outliers** de uma variável.
#
# Um boxplot é composto pelos seguintes elementos:
# - **Caixa (box)**: Representa o intervalo interquartil (**Q1 a Q3**), que contém os **50% centrais** dos dados.
# - **Linha dentro da caixa**: Indica a **mediana (Q2)**, que divide os dados em duas metades.
# - **"Bigodes" (whiskers)**: Estendem-se até os valores mínimo e máximo dentro de um limite esperado, geralmente 1,5 vezes o intervalo interquartil (IQR).
# - **Outliers**: Valores fora do limite dos bigodes são representados como pontos isolados.
#
# > ***Como interpretar um boxplot:***
# 1. **Se a caixa é estreita** → Baixa dispersão dos dados (valores concentrados).
# 2. **Se a caixa é larga** → Alta dispersão dos dados (valores mais espalhados).
# 3. **Se a mediana está próxima de um dos extremos da caixa** → Indica assimetria na distribuição.
# 4. **Se há muitos outliers** → Pode sugerir a presença de valores anômalos ou uma distribuição com cauda longa.
#
# <img src="https://miro.medium.com/v2/resize:fit:8100/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="500">

# %%
df['bill_length_mm'].plot(kind='box', vert=False)
plt.show()

# %%
def plot_boxplots(df, column):
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df, x=column)
    plt.title(f'Boxplot de {column}')
    plt.xlabel('')
    plt.ylabel(column)
    plt.tight_layout()
    plt.show()

# %%
plot_boxplots(df, 'bill_length_mm')

# %%
plot_boxplots(df, 'bill_depth_mm')

# %%
plot_boxplots(df, 'flipper_length_mm')

# %%
plot_boxplots(df, 'body_mass_g')

# %% [markdown]
# **ANOTAÇÕES:**
# > Cada ilha possui diferentes espécies, mas nenhuma possui todas as espécies

# %% [markdown]
# ### **6. Análise Multivariada**

# %% [markdown]
# Na análise multivariada, exploramos a relação entre duas ou mais variáveis simultaneamente. O objetivo é identificar padrões, correlações, associações e possíveis dependências entre os atributos. Essa etapa é essencial para levantar hipóteses mais robustas e guiar futuras análises preditivas.
#
# ***Gráficos comumente utilizados:***
# - **Gráficos de dispersão (scatter plots)**: para visualizar relações entre duas variáveis numéricas.
# - **Matriz de dispersão (pairplot)**: para explorar múltiplas combinações de variáveis numéricas.
# - **Mapas de calor (heatmaps)**: para visualizar correlações entre variáveis numéricas.
# - **Boxplots por categoria**: para comparar distribuições de variáveis numéricas em relação a categorias (por exemplo, comprimento do bico por espécie de pinguim).
# - **Gráficos de violino (violin plots)**: combinam densidade e boxplot, oferecendo uma visualização rica de distribuição por grupo.

# %% [markdown]
# #### **➡️ Histogramas por Categoria**

# %%
def plot_histograms(df, column, category_col, bins):
    plt.figure(figsize=(8, 5))
    sns.histplot(data=df, x=column, hue=category_col, kde=True, bins=bins, palette='tab10', element='step')
    plt.title(f'Histograma de {column} por {category_col}')
    plt.xlabel(column)
    plt.ylabel('Frequência')
    plt.show()

# %%
plot_histograms(df, 'bill_length_mm', 'species', bins)

# %%
plot_histograms(df, 'bill_depth_mm', 'species', bins)

# %%
plot_histograms(df, 'flipper_length_mm', 'species', bins)

# %%
plot_histograms(df, 'body_mass_g', 'species', bins)

# %% [markdown]
# #### **➡️ Boxplots por Categoria**

# %%
def plot_boxplots_category(df, column, category_col):
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df, x=category_col, y=column, hue=category_col, palette='tab10')
    plt.title(f'Boxplot de {column} por {category_col}')
    plt.xlabel(category_col)
    plt.ylabel(column)
    plt.tight_layout()
    plt.show()

# %%
plot_boxplots_category(df, 'bill_length_mm', 'species')

# %%
plot_boxplots_category(df, 'bill_depth_mm', 'species')

# %%
plot_boxplots_category(df, 'flipper_length_mm', 'species')

# %%
plot_boxplots_category(df, 'body_mass_g', 'species')

# %% [markdown]
# #### **➡️ Matriz de Correlação**

# %%
def plot_correlation_matrix(df):
    corr_df = df[df.select_dtypes(include=['float']).columns]  # Apenas atributos contínuos
    plt.figure(figsize=(10, 8))
    correlation_matrix = corr_df.corr()
    sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
    plt.title('Matriz de Correlação')
    plt.show()

# %%
plot_correlation_matrix(df)

# %% [markdown]
# #### **➡️ Matriz de Dispersão**

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
sns.pairplot(df, hue='sex')
plt.show()

# %% [markdown]
# **ANOTAÇÕES:**
#
# > Ao analisar os histogramas por categoria, observa-se que cada espécie possui uma distribuição de valores para os atributos
#
# > Existem outliers nas observações de todas as categorias de espécies
#
# > As variáveis 'flipper_length_mm' e 'body_mass_g' são fortemente correlacionadas.

# %% [markdown]
# ### **7. Tratamento de Outliers**

# %% [markdown]
# Outliers são valores que se distanciam significativamente do padrão geral dos dados. Esta etapa busca tratá-los e refletir sobre sua origem e impacto. Dependendo do contexto, outliers podem ser removidos, transformados ou mantidos, sempre com base em critérios técnicos e objetivos analíticos.

# %% [markdown]
# #### **➡️ Remoção de Outliers com Base no Intervalo Interquartil (IQR)**
#
# A técnica de remoção de outliers com base no **Intervalo Interquartil (IQR)** é uma abordagem estatística robusta que identifica e exclui valores atípicos com base na dispersão dos dados. O IQR é definido como a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1), representando a faixa central onde se encontra a maioria dos dados.
#
# Para detectar os outliers, calcula-se um limite inferior e superior:
#
# - **Limite inferior** = Q1 − 1.5 × IQR
# - **Limite superior** = Q3 + 1.5 × IQR
#
# Qualquer valor fora desse intervalo é considerado um outlier e pode ser removido. Essa técnica é particularmente útil por ser insensível à influência de valores extremos, mantendo a integridade da análise estatística. Quando aplicada a grupos distintos (por exemplo, categorias de uma variável), o cálculo do IQR é feito separadamente para cada grupo, garantindo uma detecção mais justa e contextualizada dos outliers.

# %%
def remove_outliers_iqr(df, column, category_col=None):
    if category_col:
        filtered_df = pd.DataFrame()
        for category in df[category_col].unique():
            subset = df[df[category_col] == category]
            Q1 = subset[column].quantile(0.25)
            Q3 = subset[column].quantile(0.75)
            IQR = Q3 - Q1
            mask = (subset[column] >= Q1 - 1.5 * IQR) & (subset[column] <= Q3 + 1.5 * IQR)
            filtered_df = pd.concat([filtered_df, subset[mask]])
        return filtered_df
    else:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        mask = (df[column] >= Q1 - 1.5 * IQR) & (df[column] <= Q3 + 1.5 * IQR)
        return df[mask]

# %%
df = remove_outliers_iqr(df, 'bill_length_mm', 'species')

# %%
plot_boxplots_category(df, 'bill_length_mm', 'species')

# %%
df = remove_outliers_iqr(df, 'bill_depth_mm', 'species')

# %%
plot_boxplots_category(df, 'bill_depth_mm', 'species')

# %%
df = remove_outliers_iqr(df, 'flipper_length_mm', 'species')

# %%
plot_boxplots_category(df, 'flipper_length_mm', 'species')

# %%
df = remove_outliers_iqr(df, 'body_mass_g', 'species')

# %%
plot_boxplots_category(df, 'body_mass_g', 'species')

# %%
df.shape
# Out:
# (327, 8)

# %% [markdown]
# **ANOTAÇÕES:**
# > Todos os outliers foram removidos, restando 327 linhas no dataset

# %%
df.to_csv('/content/sample_data/palmer_dataset.csv', index=False)
